# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=[1,7,2]
myvar=pd.Series(a)
print(myvar)
real=pd.Series(a, index = ["x", "y", "z"])

print(real["y"])
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64
# 7

# %% [markdown]
# ### pandas using dictionary

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)

myvar.plot()
plt.show()
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
print(pd.options.display.max_rows)
# Out:
# 60
